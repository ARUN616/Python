# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.index.to_list()#to see the index as list

# %%
df.info()

# %%
df.describe()

# %%
#to cehck the unique
df['A'].unique()

# %%
coffee=pd.read_csv("./complete-pandas-tutorial-master/warmup-data/coffee.csv")

# %%
coffee.head()

# %%
#!pip install pyarrow
#!pip install fastparquet

# %%
#loading the parquet
results=pd.read_parquet('./complete-pandas-tutorial-master/data/results.parquet')

# %%
results.head()

# %%
#olympics=pd.read_excel('./complete-pandas-tutorial-master/data/olympics-data.xlsx',sheet_name='results')

# %%
display(coffee.head(10))
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
#random data in coffee dataset
coffee.sample(10,random_state=45)
# Out:
#           Day Coffee Type  Units Sold
# 9      Friday       Latte          35
# 8      Friday    Espresso          45
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 7    Thursday       Latte          30
# 13     Sunday       Latte          35
# 1      Monday       Latte          15
# 4   Wednesday    Espresso          35
# 12     Sunday    Espresso          45

# %%
coffee.head(2)
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          15

# %%
## Loc and iloc

coffee.loc[[0,1,2]]#first 3 rows
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
#0,1, and 5 th rows
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
#to cehck the unit sol for 1s and 3 rows
coffee.loc[[0,3],['Units Sold']]
# Out:
#    Units Sold
# 0          25
# 3          20

# %%
coffee.loc[0:3,['Units Sold']]
# Out:
#    Units Sold
# 0          25
# 1          15
# 2          30
# 3          20

# %%
#using index location in instead of column name
coffee.iloc[0:3,[1,2]]
# Out:
#   Coffee Type  Units Sold
# 0    Espresso          25
# 1       Latte          15
# 2    Espresso          30

# %%
#suppose 2 nd row change the value of units sold to 10
coffee.loc[1,'Units Sold']=10

# %%
coffee.head(2)
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          10

# %%
#to retrieve specific valeus
coffee.at[1,'Coffee Type']
# Out:
# 'Latte'

# %%
coffee['Coffee Type']
# Out:
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte
# Name: Coffee Type, dtype: object

# %%
#to sort the values
coffee.sort_values(['Coffee Type','Units Sold'],ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 2     Tuesday    Espresso          30
# 0      Monday    Espresso          25

# %% [markdown]
# # Filtering Data

# %%
bios=pd.read_csv("./complete-pandas-tutorial-master/data/bios.csv")

# %%
bios.head(4)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
#to cehck athletes greater than 200cm

bios.loc[bios['height_cm']>200,['name','height_cm']].head(5)
# Out:
#                     name  height_cm
# 1080      Bozhil Lozanov      208.0
# 1673    Alexis Rubalcaba      204.0
# 2647       Milan Šrejber      203.0
# 2827  Nik'oloz Deriugini      206.0
# 2832       Elşad Qadaşev      205.0

# %%
bios.loc[(bios['height_cm']>180) & (bios['born_country']=='IND') & (bios['born_city']=='Chennai (Madras)'),['name','born_city']]
# Out:
#                    name         born_city
# 274      Anand Amritraj  Chennai (Madras)
# 275      Vijay Amritraj  Chennai (Madras)
# 278     Mahesh Bhupathi  Chennai (Madras)
# 19052    Leslie Hammond  Chennai (Madras)
# 140265      Udayan Mane  Chennai (Madras)

# %%
bios.loc[bios['name'].str.contains('Anand|Amritraj',case=False)]
# Out:
#        athlete_id                   name   born_date         born_city  \
# 274           275         Anand Amritraj  1952-03-20  Chennai (Madras)
# 275           276         Vijay Amritraj  1953-12-14  Chennai (Madras)
# 19439       19578    Kandiah Anandarajah  1938-12-04               NaN
# 44110       44449     Amorn Yuktanandana  1928-06-16               NaN
# 62933       63401    Kelly Subbanand Rao  1963-01-17               NaN
# 73369       73934    Baikuntha Manandhar  1952-12-24         Kathmandu
# 75108       75684  Ranatunge Karunananda  1936-05-21               NaN
# 76228       76812    Sompop Svadanandana  1932-10-27               NaN
#
#       born_region born_country        NOC  height_cm  weight_kg   died_date
# 274    Tamil Nadu          IND      India      185.0       77.0         NaN
# 275    Tamil Nadu          IND      India      193.0       75.0         NaN
# 19439         NaN          NaN   Malaysia        NaN        NaN         NaN
# ...

# %%
bios.loc[(bios['height_cm']>180) & (bios['born_country'].isin(['IND','NEP','CHI','USA']))]
# Out:
#         athlete_id               name   born_date         born_city  \
# 274            275     Anand Amritraj  1952-03-20  Chennai (Madras)
# 275            276     Vijay Amritraj  1953-12-14  Chennai (Madras)
# 278            279    Mahesh Bhupathi  1974-06-07  Chennai (Madras)
# 748            752          Anil Kaul  1964-12-25          Amritsar
# 767            771       Jorge Gambra  1963-07-14          Santiago
# ...            ...                ...         ...               ...
# 144099      147767      D. J. Sharabi  1992-03-07         San Mateo
# 144398      148088            Jian An  1990-09-15            Irvine
# 144400      148090   Shimisi Jieruimi  1989-04-13          Dearborn
# 144977      148686   Atle Lie McGrath  2000-04-21        Burlington
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#                   born_region born_country                         NOC  \
# 274                Tamil Nadu          IND                       India
# ...

# %%
bios.query("born_country in ('IND','NEP','CHI','USA') and height_cm>180")
# Out:
#         athlete_id               name   born_date         born_city  \
# 274            275     Anand Amritraj  1952-03-20  Chennai (Madras)
# 275            276     Vijay Amritraj  1953-12-14  Chennai (Madras)
# 278            279    Mahesh Bhupathi  1974-06-07  Chennai (Madras)
# 748            752          Anil Kaul  1964-12-25          Amritsar
# 767            771       Jorge Gambra  1963-07-14          Santiago
# ...            ...                ...         ...               ...
# 144099      147767      D. J. Sharabi  1992-03-07         San Mateo
# 144398      148088            Jian An  1990-09-15            Irvine
# 144400      148090   Shimisi Jieruimi  1989-04-13          Dearborn
# 144977      148686   Atle Lie McGrath  2000-04-21        Burlington
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#                   born_region born_country                         NOC  \
# 274                Tamil Nadu          IND                       India
# ...

# %%
## Adding/Removing Columns
coffee.head(2)
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25
# 1  Monday       Latte          10

# %%
import numpy as np
coffee['New_Prices'] = np.where((coffee['Coffee Type'] == 'Latte') & (coffee['Day'].isin(['Monday', 'Friday'])), 5.4, 9.4)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  New_Prices
# 0     Monday    Espresso          25         9.4
# 1     Monday       Latte          10         5.4
# 2    Tuesday    Espresso          30         9.4
# 3    Tuesday       Latte          20         9.4
# 4  Wednesday    Espresso          35         9.4

# %%
coffee_new=coffee[['Coffee Type','Units Sold','New_Prices']]

# %%
#to check the reveneuw
coffee['revenue']=coffee['Units Sold']*coffee['New_Prices']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  New_Prices  revenue
# 0      Monday    Espresso          25         9.4    235.0
# 1      Monday       Latte          10         5.4     54.0
# 2     Tuesday    Espresso          30         9.4    282.0
# 3     Tuesday       Latte          20         9.4    188.0
# 4   Wednesday    Espresso          35         9.4    329.0
# 5   Wednesday       Latte          25         9.4    235.0
# 6    Thursday    Espresso          40         9.4    376.0
# 7    Thursday       Latte          30         9.4    282.0
# 8      Friday    Espresso          45         9.4    423.0
# 9      Friday       Latte          35         5.4    189.0
# 10   Saturday    Espresso          45         9.4    423.0
# 11   Saturday       Latte          35         9.4    329.0
# 12     Sunday    Espresso          45         9.4    423.0
# 13     Sunday       Latte          35         9.4    329.0

# %%
#Rename the column
coffee.rename(columns={'New_Prices':'Price'},inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue
# 0      Monday    Espresso          25    9.4    235.0
# 1      Monday       Latte          10    5.4     54.0
# 2     Tuesday    Espresso          30    9.4    282.0
# 3     Tuesday       Latte          20    9.4    188.0
# 4   Wednesday    Espresso          35    9.4    329.0
# 5   Wednesday       Latte          25    9.4    235.0
# 6    Thursday    Espresso          40    9.4    376.0
# 7    Thursday       Latte          30    9.4    282.0
# 8      Friday    Espresso          45    9.4    423.0
# 9      Friday       Latte          35    5.4    189.0
# 10   Saturday    Espresso          45    9.4    423.0
# 11   Saturday       Latte          35    9.4    329.0
# 12     Sunday    Espresso          45    9.4    423.0
# 13     Sunday       Latte          35    9.4    329.0

# %%
bios_new=bios.copy()

# %%
bios_new.head(3)
# Out:
#    athlete_id                   name   born_date born_city  \
# 0           1  Jean-François Blanchy  1886-12-12  Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01    Meulan
# 2           3           Jean Borotra  1898-08-13  Biarritz
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17

# %%
bios_new['First_name']=bios_new['name'].str.split().str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  First_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
bios_new['born_date'] = pd.to_datetime(bios_new['born_date'], format='%d-%m-%Y')

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  datetime64[ns]
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  First_name    145500 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 12.2+ MB

# %%
bios_new['year']=bios_new['born_date'].dt.year

# %%
bios_new.head(1)
# Out:
#    athlete_id                   name  born_date born_city born_region  \
# 0           1  Jean-François Blanchy 1886-12-12  Bordeaux     Gironde
#
#   born_country     NOC  height_cm  weight_kg   died_date     First_name  \
# 0          FRA  France        NaN        NaN  1960-10-02  Jean-François
#
#      year
# 0  1886.0

# %%
bios['height_category']=bios['height_cm'].apply(lambda x:'short' if x>165 else('Average' if x>185 else 'Tall'))

# %% [raw]
# bios.head(5)#useful to modify specific feature

# %%
def categorize_athlete(row):
    if row['height_cm']<175 and row['weight_kg']<70:
        return 'Light_Weight'
    elif row['height_cm']<185 and row['weight_kg']<=80:
        return 'Middle Weight'
    else:
        return 'Heavy Weight'

# %%
bios['category']=bios.apply(categorize_athlete,axis=1)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       category
# 0  1960-10-02            Tall   Heavy Weight
# 1         NaN           short  Middle Weight
# 2  1994-07-17           short  Middle Weight
# ...

# %% [markdown]
# ## Merging and Concatenation

# %%
nocs=pd.read_csv('./complete-pandas-tutorial-master/data/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     First_name    year
# 0  1960-10-02  Jean-François  1886.0
# 1         NaN         Arnaud  1969.0
# 2  1994-07-17           Jean  1898.0
# 3  1978-03-20        Jacques  1895.0
# ...

# %%
#Merging NOC and bios dataset
bios_new=pd.merge(bios,nocs,left_on='born_country',right_on='NOC',how='left')

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       category NOC_y  region notes
# 0  1960-10-02            Tall   Heavy Weight   FRA  France   NaN
# ...

# %%
usa=bios[bios['born_country']=='USA'].copy()
ind=bios[bios['born_country']=='IND'].copy()

# %%
new_df=pd.concat([usa,ind])

# %%
new_df
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 140286      143790      Bajrang Punia  1994-02-26            Khudan
# 140287      143791       Deepak Punia  1999-05-19           Jhajjar
# 143996      147660        Sumit Nagal  1997-08-16           Jhajjar
# 144114      147784       Diksha Dagar  2000-12-14           Jhajjar
# 144757      148458          Arif Khan  1990-03-09           Gulmarg
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
results.head(4)
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       category
# 0  1960-10-02            Tall   Heavy Weight
# 1         NaN           short  Middle Weight
# 2  1994-07-17           short  Middle Weight
# ...

# %%
combined_df=pd.merge(results,bios,on='athlete_id',how='left')

# %%
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# # Handling Null values

# %%
coffee.loc[2:3,'Units Sold']=np.nan

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue
# 0     Monday    Espresso        25.0    9.4    235.0
# 1     Monday       Latte        10.0    5.4     54.0
# 2    Tuesday    Espresso         NaN    9.4    282.0
# 3    Tuesday       Latte         NaN    9.4    188.0
# 4  Wednesday    Espresso        35.0    9.4    329.0

# %%
coffee.isnull().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# Price          0
# revenue        0
# dtype: int64

# %%
coffee['Units Sold']=coffee['Units Sold'].interpolate()

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue
# 0     Monday    Espresso   25.000000    9.4    235.0
# 1     Monday       Latte   10.000000    5.4     54.0
# 2    Tuesday    Espresso   18.333333    9.4    282.0
# 3    Tuesday       Latte   26.666667    9.4    188.0
# 4  Wednesday    Espresso   35.000000    9.4    329.0

# %% [markdown]
# # Aggregating data

# %%
#To check india which region mostly came

bios[bios['born_country']=='IND']['born_region'].value_counts()
# Out:
# born_region
# Punjab                                 94
# Maharashtra                            56
# West Bengal                            49
# Haryana                                43
# Uttar Pradesh                          42
# Tamil Nadu                             34
# Karnataka                              32
# National Capital Territory of Delhi    32
# Kerala                                 26
# Andhra Pradesh                         23
# Madhya Pradesh                         22
# Rajasthan                              14
# Manipur                                10
# Himachal Pradesh                       10
# Gujarat                                 9
# Bihar                                   6
# Jharkhand                               5
# Assam                                   5
# Jammu and Kashmir                       5
# Uttarakhand                             4
# Tripura                                 3
# Chandigarh                              2
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue
# 0     Monday    Espresso   25.000000    9.4    235.0
# 1     Monday       Latte   10.000000    5.4     54.0
# 2    Tuesday    Espresso   18.333333    9.4    282.0
# 3    Tuesday       Latte   26.666667    9.4    188.0
# 4  Wednesday    Espresso   35.000000    9.4    329.0

# %%
#to check how many sold for each coffe type
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    253.333333
# Latte       196.666667
# Name: Units Sold, dtype: float64

# %%
#calculate avg for prices and count of units sold using agg
coffee.groupby(['Coffee Type']).agg({'Units Sold':'count','Price':'mean'})
# Out:
#              Units Sold     Price
# Coffee Type
# Espresso              7  9.400000
# Latte                 7  8.257143

# %%
#Only we need to check the revenue for coffeetype and days using pivot
pivot=coffee.pivot(columns='Coffee Type',index='Day',values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso  Latte
# Day
# Friday          423.0  189.0
# Monday          235.0   54.0
# Saturday        423.0  329.0
# Sunday          423.0  329.0
# Thursday        376.0  282.0
# Tuesday         282.0  188.0
# Wednesday       329.0  235.0

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       612.0
# Monday       289.0
# Saturday     752.0
# Sunday       752.0
# Thursday     658.0
# Tuesday      470.0
# Wednesday    564.0
# dtype: float64

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category       category
# 0  1960-10-02            Tall   Heavy Weight
# 1         NaN           short  Middle Weight
# 2  1994-07-17           short  Middle Weight
# ...

# %%
#to check how many person born in each year
bios['born_date']=pd.to_datetime(bios.born_date)

# %%
bios['month_born']=bios['born_date'].dt.month_name
bios['year_born']=bios['born_date'].dt.year
bios.groupby([bios['month_born'],bios['year_born']])['name'].count().sort_values(ascending=False).reset_index()
# Out:
#       month_born  year_born  name
# 0            1.0     1970.0   239
# 1            1.0     1972.0   229
# 2            1.0     1975.0   227
# 3            1.0     1986.0   227
# 4            1.0     1985.0   225
# ...          ...        ...   ...
# 1880         9.0     1852.0     1
# 1881         9.0     1854.0     1
# 1882         9.0     1855.0     1
# 1883         9.0     1857.0     1
# 1884        12.0     2006.0     1
#
# [1885 rows x 3 columns]

# %%
bios['month_year'] = bios['born_date'].dt.strftime('%b %Y')
result = bios.groupby('month_year')['name'].count().reset_index()
result
# Out:
#      month_year  name
# 0      Apr 1846     2
# 1      Apr 1847     1
# 2      Apr 1850     1
# 3      Apr 1852     2
# 4      Apr 1855     2
# ...         ...   ...
# 1880   Sep 2002    69
# 1881   Sep 2003    40
# 1882   Sep 2004    40
# 1883   Sep 2005    12
# 1884   Sep 2006     1
#
# [1885 rows x 2 columns]

# %% [markdown]
# # Advance Functionality

# %%
coffee['yesterday_revenue']=coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue
# 0      Monday    Espresso   25.000000    9.4    235.0                NaN
# 1      Monday       Latte   10.000000    5.4     54.0                NaN
# 2     Tuesday    Espresso   18.333333    9.4    282.0              235.0
# 3     Tuesday       Latte   26.666667    9.4    188.0               54.0
# 4   Wednesday    Espresso   35.000000    9.4    329.0              282.0
# 5   Wednesday       Latte   25.000000    9.4    235.0              188.0
# 6    Thursday    Espresso   40.000000    9.4    376.0              329.0
# 7    Thursday       Latte   30.000000    9.4    282.0              235.0
# 8      Friday    Espresso   45.000000    9.4    423.0              376.0
# 9      Friday       Latte   35.000000    5.4    189.0              282.0
# 10   Saturday    Espresso   45.000000    9.4    423.0              423.0
# 11   Saturday       Latte   35.000000    9.4    329.0              189.0
# ...

# %%
coffee['pct_change']=round((coffee['revenue']/coffee['yesterday_revenue'])*100,2)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0     Monday    Espresso   25.000000    9.4    235.0                NaN
# 1     Monday       Latte   10.000000    5.4     54.0                NaN
# 2    Tuesday    Espresso   18.333333    9.4    282.0              235.0
# 3    Tuesday       Latte   26.666667    9.4    188.0               54.0
# 4  Wednesday    Espresso   35.000000    9.4    329.0              282.0
#
#    pct_change
# 0         NaN
# 1         NaN
# 2      120.00
# 3      348.15
# 4      116.67

# %%
# In bios dataset to cehck the highest height rank

bios['height_rank']=bios['height_cm'].rank(ascending=True)

# %%
bios.drop('height_rang',axis=1,inplace=True)

# %%
bios.sort_values(by='height_rank')
# Out:
#         athlete_id                   name  born_date           born_city  \
# 28619        28832        Rosario Briones 1953-10-05     San Luis Potosí
# 4515          4530          Lyton Mphande 1963-05-14                 NaN
# 4516          4531          Helman Palije 1967-06-24                 NaN
# 4664          4681       Salvador Miranda 1949-09-13                 NaN
# 4517          4532         Boston Simbeye 1959-12-24                 NaN
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                NOC  height_cm  \
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0     Monday    Espresso   25.000000    9.4    235.0                NaN
# 1     Monday       Latte   10.000000    5.4     54.0                NaN
# 2    Tuesday    Espresso   18.333333    9.4    282.0              235.0
# 3    Tuesday       Latte   26.666667    9.4    188.0               54.0
# 4  Wednesday    Espresso   35.000000    9.4    329.0              282.0
#
#    pct_change
# 0         NaN
# 1         NaN
# 2      120.00
# 3      348.15
# 4      116.67

# %%
coffee['Cumulative_revenue']=coffee['revenue'].cumsum()

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0     Monday    Espresso   25.000000    9.4    235.0                NaN
# 1     Monday       Latte   10.000000    5.4     54.0                NaN
# 2    Tuesday    Espresso   18.333333    9.4    282.0              235.0
# 3    Tuesday       Latte   26.666667    9.4    188.0               54.0
# 4  Wednesday    Espresso   35.000000    9.4    329.0              282.0
#
#    pct_change  Cumulative_revenue
# 0         NaN               235.0
# 1         NaN               289.0
# 2      120.00               571.0
# 3      348.15               759.0
# 4      116.67              1088.0

# %%
# Calculate 7-day rolling average of 'revenue' column
coffee['Rolling_Avg_revenue'] = coffee['revenue'].rolling(window=3).mean()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0      Monday    Espresso   25.000000    9.4    235.0                NaN
# 1      Monday       Latte   10.000000    5.4     54.0                NaN
# 2     Tuesday    Espresso   18.333333    9.4    282.0              235.0
# 3     Tuesday       Latte   26.666667    9.4    188.0               54.0
# 4   Wednesday    Espresso   35.000000    9.4    329.0              282.0
# 5   Wednesday       Latte   25.000000    9.4    235.0              188.0
# 6    Thursday    Espresso   40.000000    9.4    376.0              329.0
# 7    Thursday       Latte   30.000000    9.4    282.0              235.0
# 8      Friday    Espresso   45.000000    9.4    423.0              376.0
# 9      Friday       Latte   35.000000    5.4    189.0              282.0
# 10   Saturday    Espresso   45.000000    9.4    423.0              423.0
# 11   Saturday       Latte   35.000000    9.4    329.0              189.0
# ...

# %% [markdown]
# # New Functionality

# %%
results_numpy=pd.read_csv('./complete-pandas-tutorial-master/data/results.csv')
results_arrow=pd.read_csv('./complete-pandas-tutorial-master/data/results.csv',engine='pyarrow',
                         dtype_backend='pyarrow')

# %%
results_numpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB
